# %% [markdown]
# Customer Data Preprocessing Pipeline

# %% [markdown]
# “Data preprocessing is the process of cleaning and preparing raw data before analysis. In this project, I implemented a complete preprocessing pipeline.”

# %% [markdown]
# “For this project, I used the following tools for data preprocessing.”
# Pandas
#     Data loading
#     Cleaning
#     Transformation
# NumPy
#     Numerical operations
#     Statistical analysis
# Scikit-learn
# Encoding
# Feature Scaling

# %% [markdown]
# “This project follows ETL (Extract, Transform, Load) pipeline.”
#
# Extract → Load dataset
# Transform → Cleaning + processing
# Load → Save final data

# %% [markdown]
# STEP 1: DATA INGESTION (EXTRACT)

# %%
import pandas as pd

df = pd.read_csv("C:/Users/bharath js/Downloads/Customer DataSet.csv")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# I extracted data from a CSV file using Pandas. The dataset was successfully loaded into a Pandas DataFrame and verified using basic inspection operations.”

# %% [markdown]
# ## Data Extraction (Data Ingestion)
#
# ## Data Extraction Methods
#
# - CSV File
#   - read_csv() is used to load CSV data
#
# - Excel File
#   - read_excel() is used to load Excel data
#
# - JSON File
#   - read_json() is used to load JSON data
#
# - Text File
#   - read_table() or read_csv() is used
#
# - SQL Database
#   - read_sql() is used to load data from database
#
# - Online Source (URL)
#   - read_csv("url") is used to load online data
#
# - Manual Data
#   - DataFrame() is used to create data manually
# pd.read_csv()
# pd.read_excel()
# pd.read_json()
# pd.read_table()
# pd.read_sql()

# %% [markdown]
# ## Data Understanding
#
# - Data understanding is used to analyze dataset structure
#
# - Pandas functions:
#   - info() → column details and data types
#   - describe() → statistical summary
#   - shape → number of rows and columns
#   - columns → column names
#   - dtypes → data types
#   - nunique() → unique values
#   - value_counts() → frequency of values
#   - corr() → correlation between columns
#
# - NumPy functions:
#   - array() → convert data into array
#   - mean() → average value
#   - median() → middle value
#   - std() → standard deviation
#   - min() → minimum value
#   - max() → maximum value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.nunique()
# Out:
# CUST_ID                             8950
# BALANCE                             8871
# BALANCE_FREQUENCY                     43
# PURCHASES                           6203
# ONEOFF_PURCHASES                    4014
# INSTALLMENTS_PURCHASES              4452
# CASH_ADVANCE                        4323
# PURCHASES_FREQUENCY                   47
# ONEOFF_PURCHASES_FREQUENCY            47
# PURCHASES_INSTALLMENTS_FREQUENCY      47
# CASH_ADVANCE_FREQUENCY                54
# CASH_ADVANCE_TRX                      65
# PURCHASES_TRX                        173
# CREDIT_LIMIT                         205
# PAYMENTS                            8711
# MINIMUM_PAYMENTS                    8636
# PRC_FULL_PAYMENT                      47
# TENURE                                 7
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
import numpy as np

data_array = np.array(df.select_dtypes(include=np.number))

# %%
np.mean(data_array, axis=0)
# Out:
# array([1.56447483e+03, 8.77270726e-01, 1.00320483e+03, 5.92437371e+02,
#        4.11067645e+02, 9.78871112e+02, 4.90350548e-01, 2.02457684e-01,
#        3.64437342e-01, 1.35144200e-01, 3.24882682e+00, 1.47098324e+01,
#                   nan, 1.73314385e+03,            nan, 1.53714648e-01,
#        1.15173184e+01])

# %%
np.median(data_array, axis=0)
# Out:
# array([8.73385231e+02, 1.00000000e+00, 3.61280000e+02, 3.80000000e+01,
#        8.90000000e+01, 0.00000000e+00, 5.00000000e-01, 8.33330000e-02,
#        1.66667000e-01, 0.00000000e+00, 0.00000000e+00, 7.00000000e+00,
#                   nan, 8.56901546e+02,            nan, 0.00000000e+00,
#        1.20000000e+01])

# %%
import pandas as pd

# Check column types
print(df.dtypes)

# Keep only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Compute correlation
corr_matrix = numeric_df.corr()
print(corr_matrix)
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# ...

# %%
# Check total missing values per column
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute numeric correlations
corr_matrix = df.corr(numeric_only=True)

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Data Cleaning & Preprocessing

# %%
#STEP 1: CHECK MISSING VALUES
# Count missing values per column
df.isnull().sum()
#Helps identify which columns need cleaning or filling.
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#STEP 2: HANDLE MISSING VALUES

#Option A: Drop rows with missing values

df = df.dropna()

# %%
# Count duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
# Example: Remove outliers beyond 3 standard deviations
numeric_cols = df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    mean = df[col].mean()
    std = df[col].std()
    df = df[(df[col] >= mean - 3*std) & (df[col] <= mean + 3*std)]

# %%
# Check dataframe info
df.info()

# Check missing values
df.isnull().sum()

# Check first 5 rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6490 entries, 0 to 8880
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           6490 non-null   object
#  1   BALANCE                           6490 non-null   float64
#  2   BALANCE_FREQUENCY                 6490 non-null   float64
#  3   PURCHASES                         6490 non-null   float64
#  4   ONEOFF_PURCHASES                  6490 non-null   float64
#  5   INSTALLMENTS_PURCHASES            6490 non-null   float64
#  6   CASH_ADVANCE                      6490 non-null   float64
#  7   PURCHASES_FREQUENCY               6490 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        6490 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  6490 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            6490 non-null   float64
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Numeric columns
numeric_cols = df.select_dtypes(include='number').columns
print("Numeric columns:", numeric_cols)
# Out:
# Numeric columns: Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
# Example: create Age_Group from Age
if 'Age' in df.columns:
    df['Age_Group'] = pd.cut(
        df['Age'],
        bins=[0, 18, 35, 60, 100],
        labels=['Child', 'Youth', 'Adult', 'Senior']
    )

# %%
df.head()
df[numeric_cols].describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# count  6490.000000        6490.000000  6490.000000       6490.000000
# mean      0.153285           0.866157     0.121301          0.109130
# std       0.183531           0.261887     0.148518          0.185358
# min       0.000000           0.000000     0.000000          0.000000
# 25%       0.014527           0.875000     0.008921          0.000000
# 50%       0.097870           1.000000     0.067452          0.000005
# 75%       0.211954           1.000000     0.176859          0.147009
# max       1.000000           1.000000     1.000000          1.000000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             6490.000000   6490.000000          6490.000000
# mean                 0.128634      0.090104             0.476891
# std                  0.191203      0.164751             0.391804
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.to_csv('final_dataset.csv', index=False)
